# %%
import pandas as pd
import seaborn as sns
from dfply import *

airbnb = pd.read_csv('https://raw.githubusercontent.com/si4ch/Data_Analysis_Workshops/refs/heads/main/data/airbnb.csv')
airbnb >> head(3)
# Out:
#    Unnamed: 0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
#
#     host_id host_name          neighbourhood_full            coordinates  \
# 0  20583125    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1  82746113   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
# 2     78251    Leslie  Brooklyn, Brooklyn Heights   (40.7007, -73.99517)
#
#          room_type price  number_of_reviews last_review  reviews_per_month  \
# 0     Private room   45$                 10  2018-12-12                0.7
# 1  Entire home/apt  135$                  1  2019-06-30                1.0
# 2  Entire home/apt  150$                  0         NaN                NaN
#
# ...

# %% [markdown]
# change prices from float, (we should change 0 to something but we don t)
# question nr1: what is the difference between normalizing and standardizing (here is about the prices)
#
# learn for me: minmax function???
# scipy.stats most important library
#
# homework: find funtions to print object table

# %%
airbnb['price'] = airbnb['price'].str.strip("$")
# Print header to make sure change was done
airbnb['price'].head()
# Out:
# 0     45
# 1    135
# 2    150
# 3     86
# 4    160
# Name: price, dtype: object

# %%
# Convert price to float
airbnb['price'] = airbnb['price'].astype('float')
# Calculate mean of price after conversion
avg = airbnb['price'].mean()
airbnb['price'] = airbnb['price'].fillna(avg)

# %%
airbnb['logprice'] = np.log(airbnb['price'])
sns.histplot(airbnb['price'])
# Out:
# c:\Program Files\Python310\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='price', ylabel='Count'>
